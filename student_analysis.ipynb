# %% [markdown]
# **Student Performance Analysis**

# %%
import pandas as pd

# Load the datasets
d1 = pd.read_csv(r"D:\meena\student-mat.csv")
d2 = pd.read_csv(r"D:\meena\studentpor.csv")

# Merge the datasets on the given columns
d3 = pd.merge(
    d1,
    d2,
    on=[
        "school", "sex", "age", "address", "famsize", "Pstatus",
        "Medu", "Fedu", "Mjob", "Fjob", "reason", "nursery", "internet"
    ]
)

# Print number of rows
print(len(d3),"students")  # should give 382 students
# Out:
# 382 students

# %%
d3.to_csv(r"D:\meena\merged_students.csv", index=False)

# %% [markdown]
# **Step : 1 Load the Dataset**

# %%
#importing necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#load dataset
data = pd.read_csv(r"D:\meena\merged_students.csv")
df = pd.DataFrame(data)
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel_y freetime_y  goout_y  Dalc_y  Walc_y health_y absences_y G1_y G2_y  \
# 0        4          3        4       1       1        3          4    0   11
# 1        5          3        3       1       1        3          2    9   11
# 2        4          3        2       2       3        3          6   12   13
# 3        3          2        2       1       1        5          0   14   14
# 4        4          3        2       1       2        5          0   11   13
#
#   G3_y
# 0   11
# 1   11
# 2   12
# ...

# %% [markdown]
# **Step : 2 Explore and Clean Data**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 382 entries, 0 to 381
# Data columns (total 53 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   school        382 non-null    object
#  1   sex           382 non-null    object
#  2   age           382 non-null    int64
#  3   address       382 non-null    object
#  4   famsize       382 non-null    object
#  5   Pstatus       382 non-null    object
#  6   Medu          382 non-null    int64
#  7   Fedu          382 non-null    int64
#  8   Mjob          382 non-null    object
#  9   Fjob          382 non-null    object
#  10  reason        382 non-null    object
#  11  guardian_x    382 non-null    object
#  12  traveltime_x  382 non-null    int64
#  13  studytime_x   382 non-null    int64
#  14  failures_x    382 non-null    int64
#  15  schoolsup_x   382 non-null    object
#  16  famsup_x      382 non-null    object
#  17  paid_x        382 non-null    object
# ...

# %%
#check missing values
print("null values :\n",df.isnull().sum())
# Out:
# null values :
#  school          0
# sex             0
# age             0
# address         0
# famsize         0
# Pstatus         0
# Medu            0
# Fedu            0
# Mjob            0
# Fjob            0
# reason          0
# guardian_x      0
# traveltime_x    0
# studytime_x     0
# failures_x      0
# schoolsup_x     0
# famsup_x        0
# paid_x          0
# activities_x    0
# nursery         0
# higher_x        0
# internet        0
# romantic_x      0
# famrel_x        0
# freetime_x      0
# goout_x         0
# Dalc_x          0
# Walc_x          0
# health_x        0
# absences_x      0
# G1_x            0
# G2_x            0
# G3_x            0
# guardian_y      0
# traveltime_y    0
# studytime_y     0
# failures_y      0
# schoolsup_y     0
# famsup_y        0
# paid_y          0
# activities_y    0
# higher_y        0
# romantic_y      0
# famrel_y        0
# freetime_y      0
# goout_y         0
# Dalc_y          0
# Walc_y          0
# health_y        0
# ...

# %%
#remove duplicates
print("Duplicates :",df.duplicated().sum())
# Out:
# Duplicates : 0

# %%
#shape and types of data
print("Shape :",df.shape)
print("Data Types :\n",df.dtypes)
# Out:
# Shape : (382, 53)
# Data Types :
#  school          object
# sex             object
# age              int64
# address         object
# famsize         object
# Pstatus         object
# Medu             int64
# Fedu             int64
# Mjob            object
# Fjob            object
# reason          object
# guardian_x      object
# traveltime_x     int64
# studytime_x      int64
# failures_x       int64
# schoolsup_x     object
# famsup_x        object
# paid_x          object
# activities_x    object
# nursery         object
# higher_x        object
# internet        object
# romantic_x      object
# famrel_x         int64
# freetime_x       int64
# goout_x          int64
# Dalc_x           int64
# Walc_x           int64
# health_x         int64
# absences_x       int64
# G1_x             int64
# G2_x             int64
# G3_x             int64
# guardian_y      object
# traveltime_y     int64
# studytime_y      int64
# failures_y       int64
# schoolsup_y     object
# ...

# %% [markdown]
# **Step : 3 Analysis Questions**

# %%
average_g3_math = d3["G3_x"].mean()
average_g3_por = d3["G3_y"].mean()

print("Average Final Grade (g3_x) = ", average_g3_math)
print("Average Final Grade (g3_y) = ", average_g3_por)
# Out:
# Average Final Grade (g3_x) =  10.387434554973822
# Average Final Grade (g3_y) =  12.515706806282722

# %%
above_math = (d3["G3_x"] > 15).sum()
above_por = (d3["G3_y"] > 15).sum()

print("Students scoring above 15 in Mat = ", above_math)
print("Students scoring above 15 in Por = ", above_por)
# Out:
# Students scoring above 15 in Mat =  42
# Students scoring above 15 in Por =  58

# %%
corr_math = d3["studytime_x"].corr(d3["G3_x"])
print("Correlation (studytime vs performance in Mat) =", corr_math)

corr_por = d3["studytime_y"].corr(d3["G3_y"])
print("Correlation (studytime vs performance in Por) =", corr_por)
# Out:
# Correlation (studytime vs performance in Mat) = 0.09133868385089479
# Correlation (studytime vs performance in Por) = 0.28376199517926826

# %%
gen_per_math = d3.groupby("sex")["G3_x"].mean()
gen_per_por = d3.groupby("sex")["G3_y"].mean()

print("Average performance by gender (Mat):\n", gen_per_math)
print("\nAverage performance by gender (Port):\n", gen_per_por)
# Out:
# Average performance by gender (Mat):
#  sex
# F     9.838384
# M    10.978261
# Name: G3_x, dtype: float64
#
# Average performance by gender (Port):
#  sex
# F    13.085859
# M    11.902174
# Name: G3_y, dtype: float64

# %% [markdown]
# **Step : 4 Visualization**

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian_x', 'traveltime_x', 'studytime_x',
#        'failures_x', 'schoolsup_x', 'famsup_x', 'paid_x', 'activities_x',
#        'nursery', 'higher_x', 'internet', 'romantic_x', 'famrel_x',
#        'freetime_x', 'goout_x', 'Dalc_x', 'Walc_x', 'health_x', 'absences_x',
#        'G1_x', 'G2_x', 'G3_x', 'guardian_y', 'traveltime_y', 'studytime_y',
#        'failures_y', 'schoolsup_y', 'famsup_y', 'paid_y', 'activities_y',
#        'higher_y', 'romantic_y', 'famrel_y', 'freetime_y', 'goout_y', 'Dalc_y',
#        'Walc_y', 'health_y', 'absences_y', 'G1_y', 'G2_y', 'G3_y'],
#       dtype='object')

# %%
plt.figure(figsize=(8,6))
sns.histplot(d3["G1_x"], kde=True, bins=10, color="pink")
plt.title("Histogram of Mat Grade (G1)")
plt.xlabel("G1 (Mat)")
plt.ylabel("Number of Students")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.histplot(d3["G1_y"], kde=True, bins=10, color="skyblue")
plt.title("Histogram of Por Grade (G1)")
plt.xlabel("G1 (Por)")
plt.ylabel("Number of Students")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.histplot(d3["G2_x"], kde=True, bins=10, color="green")
plt.title("Histogram of Mat Grade (G2)")
plt.xlabel("G2 (Mat)")
plt.ylabel("Number of Students")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.histplot(d3["G2_y"], kde=True, bins=10, color="green")
plt.title("Histogram of por Grade (G2)")
plt.xlabel("G2 (por)")
plt.ylabel("Number of Students")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.histplot(d3["G3_x"], kde=True, bins=10, color="yellow")
plt.title("Histogram of Mat Final Grade (G3)")
plt.xlabel("G3 (Mat)")
plt.ylabel("Number of Students")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.histplot(d3["G3_y"], kde=True, bins=10, color="yellow")
plt.title("Histogram of por Final Grade (G3)")
plt.xlabel("G3 (por)")
plt.ylabel("Number of Students")
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(d3['studytime_x'], d3['G3_x'], color="red")
plt.title("Scatterplot of Studytime vs Final Grade (Mat)")
plt.xlabel("Studytime (Mat)")
plt.ylabel("Final Grade (G3 Mat)")
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(d3['studytime_y'], d3['G3_y'], color="red")
plt.title("Scatterplot of Studytime vs Final Grade (por)")
plt.xlabel("Studytime (por)")
plt.ylabel("Final Grade (G3 por)")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.barplot(x="sex", y="G3_x", data=d3, palette="pastel")
plt.title("Average Final Grade by Gender (Mat)")
plt.xlabel("Gender")
plt.ylabel("Final Grade (Mat)")
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9172\3768327037.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="sex", y="G3_x", data=d3, palette="pastel")

# %%
plt.figure(figsize=(8,6))
sns.barplot(x="sex", y="G3_y", data=d3, palette="dark")
plt.title("Average Final Grade by Gender (por)")
plt.xlabel("Gender")
plt.ylabel("Final Grade (por)")
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9172\3280240815.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="sex", y="G3_y", data=d3, palette="dark")
