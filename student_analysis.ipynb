# %% [markdown]
# **Student Performance Analysis**

# %% [markdown]
# **Step : 1 Load the Dataset**

# %%
#importing necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#load dataset
data = pd.read_csv(r"D:\meena\student-mat.csv")
df = pd.DataFrame(data)
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# **Step : 2 Explore and Clean Data**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
#check missing values
print("null values :\n",df.isnull().sum())
# Out:
# null values :
#  school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
#remove duplicates
print("Duplicates :",df.duplicated().sum())
# Out:
# Duplicates : 0

# %%
#shape and types of data
print("Shape :",df.shape)
print("Data Types :\n",df.dtypes)
# Out:
# Shape : (395, 33)
# Data Types :
#  school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %% [markdown]
# **Step : 3 Analysis Questions**

# %%
# Average final grade (g3)
average_g3 = df["G3"].mean()
print("Average Final Grade (G3) = ",average_g3)
# Out:
# Average Final Grade (G3) =  10.415189873417722

# %%
# how many students scored above 15
above = (df["G3"]>15) . sum()
print("Sum of students who have scored above 15 = ",above)
# Out:
# Sum of students who have scored above 15 =  40

# %%
#correlation of studytime and performance
Correlation = df["studytime"].corr(df["G3"])
print("correlation = ",Correlation)
# Out:
# correlation =  0.09781968965319636

# %%
#which gender performs better on average
gen_per = df.groupby("sex")["G3"].mean()
print("Gender performance on average \n",gen_per)
# Out:
# Gender performance on average
#  sex
# F     9.966346
# M    10.914439
# Name: G3, dtype: float64

# %% [markdown]
# **Analysis Question Answers**

# %% [markdown]
# Average Final Grade (G3) =  10.415189873417722

# %% [markdown]
# Sum of students who have scored above 15 =  40

# %% [markdown]
# correlation =  0.09781968965319636

# %% [markdown]
# Gender performance on average
#  sex
# F     9.966346
# M    10.914439
# Name: G3, dtype: float64

# %% [markdown]
# **Step : 4 Visualization**

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
#Histogram
plt.figure(figsize=(8,6))
sns.histplot(df["G1"],kde=True,bins = 10,color="pink")
plt.title("Histogram of Grade(G1)")
plt.xlabel("G1")
plt.ylabel("Number of students")
plt.show()

# %%
#Histogram
plt.figure(figsize=(8,6))
sns.histplot(df["G2"],kde=True,bins = 10,color="green")
plt.title("Histogram of Grade(G2)")
plt.xlabel("G2")
plt.ylabel("Number of students")
plt.show()

# %%
#Histogram
plt.figure(figsize=(8,6))
sns.histplot(df["G3"],kde=True,bins = 10,color="yellow")
plt.title("Histogram of Grade(G3)")
plt.xlabel("G3")
plt.ylabel("Number of students")
plt.show()

# %%
#Scatterplot
plt.figure(figsize=(8,6))
plt.scatter(df['studytime'],df['G3'],color="red")
plt.title("Scatterplot of studytime and final grade")
plt.xlabel('Studytime')
plt.ylabel('G3')
plt.show()

# %%
#Average final grade by gender
plt.figure(figsize=(8,6))
sns.barplot(x = "sex", y = "G3", data = df, palette="pastel")
plt.title("Average final grade by gender")
plt.xlabel("Gender")
plt.ylabel("Final Grade")
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14740\1399572322.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = "sex", y = "G3", data = df, palette="pastel")
